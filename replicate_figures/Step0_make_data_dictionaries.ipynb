# %%
import sys
sys.path.append('../')

# %%
from plants_and_TCR.make_data_dictionary import save_and_open_dict

# %%
from plants_and_TCR.make_data_dictionary import load_cmip6_dictionary
cmip6_dict = load_cmip6_dictionary.load_dictionary()
# Out:
# ******************
# loading model: BCC-CSM2-MR
# variable: areacella
# variable: sftlf
# variable: sftgif
# loading run: 1pctCO2-bgc
# variable: huss
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: clt
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: lai
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: gpp
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: evspsbl
# variable: tran
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: pr
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlds
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsds
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlus
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsus
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: hfls
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: hfss
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsdscs
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsuscs
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rldscs
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsdt
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlut
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsut
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: tas
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# loading run: 1pctCO2-rad
# variable: huss
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: clt
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: lai
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: gpp
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: evspsbl
# variable: tran
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: pr
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlds
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsds
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlus
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsus
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: hfls
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: hfss
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsdscs
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsuscs
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rldscs
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsdt
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlut
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsut
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: tas
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# loading run: 1pctCO2
# variable: hurs
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: huss
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: clt
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: lai
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: gpp
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: evspsbl
# variable: tran
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: pr
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# ...
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# ../plants_and_TCR/make_data_dictionary/load_cmip6_dictionary.py:105: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)#, combine='by_coords' ,combine='nested'
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,

# %%
save_and_open_dict.save_dict(dict_to_save=cmip6_dict, dict_name='cmip6_dict')

# %%
from plants_and_TCR.make_data_dictionary import load_cmip5_dictionary
cmip5_dict = load_cmip5_dictionary.load_dictionary()
save_dict.save_dict(dict_to_save=cmip5_dict, dict_name='cmip5_dict')
# Out:
# loading model: MPI-ESM-LR
# variable: areacella
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:60: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: sftlf
# variable: sftgif
# loading run: esmFixClim1
# variable: hfls
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:72: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:84: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: hfss
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: ps
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: evspsbl
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: tas
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: ts
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: ps
# variable: pr
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: sfcWind
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: tran
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: gpp
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: lai
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: mrro
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlds
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlus
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlut
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsds
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsdt
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsus
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsut
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rldscs
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsdscs
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsuscs
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsutcs
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlutcs
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# loading run: 1pctCO2
# variable: hfls
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: hfss
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: ps
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: evspsbl
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: tas
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: ts
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: ps
# variable: pr
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: sfcWind
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: tran
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: gpp
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: lai
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: mrro
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlds
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlus
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rlut
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsds
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsdt
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsus
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsut
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rldscs
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: rsdscs
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# ...
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# loading run: 1pctCO2
# loading run: esmFdbk1
# loading run: piControl
# loading run: abrupt4xCO2
# loading model: BNU-ESM
# variable: areacella
# variable: sftlf
# loading run: esmFixClim1
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:60: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:72: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# loading run: 1pctCO2
# variable: hfls
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: hfss
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: hurs
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: ps
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: evspsbl
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: tas
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: ps
# variable: pr
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: sfcWind
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: tran
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: gpp
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: lai
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: mrro
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# variable: mrso
# ../plants_and_TCR/make_data_dictionary/load_cmip5_dictionary.py:116: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds_cmip = xr.open_mfdataset(filenamelist)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# loading run: esmFdbk1
# loading run: piControl
# loading run: abrupt4xCO2

# %%
from plants_and_TCR.make_data_dictionary import combine_cmip5_and_cmip6
cmip_dict=combine_cmip5_and_cmip6.combine_cmip_dictionaries()
save_and_open_dict.save_dict(dict_to_save=cmip_dict, dict_name='cmip_dict')

# %% [markdown]
# ### Check what is in dictionary

# %%
for key in cmip_dict.keys():
    print(key)
# Out:
# BCC-CSM2-MR_areacella
# BCC-CSM2-MR_sftlf
# BCC-CSM2-MR_sftgif
# BCC-CSM2-MR_1pctCO2-bgc_huss
# BCC-CSM2-MR_1pctCO2-bgc_clt
# BCC-CSM2-MR_1pctCO2-bgc_lai
# BCC-CSM2-MR_1pctCO2-bgc_gpp
# BCC-CSM2-MR_1pctCO2-bgc_evspsbl
# BCC-CSM2-MR_1pctCO2-bgc_tran
# BCC-CSM2-MR_1pctCO2-bgc_pr
# BCC-CSM2-MR_1pctCO2-bgc_rlds
# BCC-CSM2-MR_1pctCO2-bgc_rsds
# BCC-CSM2-MR_1pctCO2-bgc_rlus
# BCC-CSM2-MR_1pctCO2-bgc_rsus
# BCC-CSM2-MR_1pctCO2-bgc_hfls
# BCC-CSM2-MR_1pctCO2-bgc_hfss
# BCC-CSM2-MR_1pctCO2-bgc_rsdscs
# BCC-CSM2-MR_1pctCO2-bgc_rsuscs
# BCC-CSM2-MR_1pctCO2-bgc_rldscs
# BCC-CSM2-MR_1pctCO2-bgc_rsdt
# BCC-CSM2-MR_1pctCO2-bgc_rlut
# BCC-CSM2-MR_1pctCO2-bgc_rsut
# BCC-CSM2-MR_1pctCO2-bgc_tas
# BCC-CSM2-MR_1pctCO2-rad_huss
# BCC-CSM2-MR_1pctCO2-rad_clt
# BCC-CSM2-MR_1pctCO2-rad_lai
# BCC-CSM2-MR_1pctCO2-rad_gpp
# BCC-CSM2-MR_1pctCO2-rad_evspsbl
# BCC-CSM2-MR_1pctCO2-rad_tran
# BCC-CSM2-MR_1pctCO2-rad_pr
# BCC-CSM2-MR_1pctCO2-rad_rlds
# BCC-CSM2-MR_1pctCO2-rad_rsds
# BCC-CSM2-MR_1pctCO2-rad_rlus
# BCC-CSM2-MR_1pctCO2-rad_rsus
# BCC-CSM2-MR_1pctCO2-rad_hfls
# BCC-CSM2-MR_1pctCO2-rad_hfss
# BCC-CSM2-MR_1pctCO2-rad_rsdscs
# BCC-CSM2-MR_1pctCO2-rad_rsuscs
# BCC-CSM2-MR_1pctCO2-rad_rldscs
# BCC-CSM2-MR_1pctCO2-rad_rsdt
# BCC-CSM2-MR_1pctCO2-rad_rlut
# BCC-CSM2-MR_1pctCO2-rad_rsut
# BCC-CSM2-MR_1pctCO2-rad_tas
# BCC-CSM2-MR_1pctCO2_hurs
# BCC-CSM2-MR_1pctCO2_huss
# BCC-CSM2-MR_1pctCO2_clt
# BCC-CSM2-MR_1pctCO2_lai
# BCC-CSM2-MR_1pctCO2_gpp
# BCC-CSM2-MR_1pctCO2_evspsbl
# BCC-CSM2-MR_1pctCO2_tran
# BCC-CSM2-MR_1pctCO2_pr
# BCC-CSM2-MR_1pctCO2_rlds
# BCC-CSM2-MR_1pctCO2_rsds
# BCC-CSM2-MR_1pctCO2_rlus
# BCC-CSM2-MR_1pctCO2_rsus
# BCC-CSM2-MR_1pctCO2_hfls
# BCC-CSM2-MR_1pctCO2_hfss
# BCC-CSM2-MR_1pctCO2_rsdscs
# BCC-CSM2-MR_1pctCO2_rsuscs
# BCC-CSM2-MR_1pctCO2_rldscs
# BCC-CSM2-MR_1pctCO2_rsdt
# BCC-CSM2-MR_1pctCO2_rlut
# BCC-CSM2-MR_1pctCO2_rsut
# BCC-CSM2-MR_1pctCO2_tas
# BCC-CSM2-MR_piControl_clt
# BCC-CSM2-MR_piControl_lai
# BCC-CSM2-MR_piControl_gpp
# BCC-CSM2-MR_piControl_evspsbl
# BCC-CSM2-MR_piControl_tran
# BCC-CSM2-MR_piControl_rlds
# BCC-CSM2-MR_piControl_rsds
# BCC-CSM2-MR_piControl_rlus
# BCC-CSM2-MR_piControl_rsus
# BCC-CSM2-MR_piControl_hfls
# BCC-CSM2-MR_piControl_rsdscs
# BCC-CSM2-MR_piControl_rsuscs
# BCC-CSM2-MR_piControl_rldscs
# BCC-CSM2-MR_piControl_rsdt
# BCC-CSM2-MR_piControl_rlut
# BCC-CSM2-MR_piControl_rsut
# BCC-CSM2-MR_piControl_tas
# CanESM5_areacella
# CanESM5_sftlf
# CanESM5_sftgif
# CanESM5_1pctCO2-bgc_hurs
# CanESM5_1pctCO2-bgc_huss
# CanESM5_1pctCO2-bgc_clt
# CanESM5_1pctCO2-bgc_lai
# CanESM5_1pctCO2-bgc_gpp
# CanESM5_1pctCO2-bgc_evspsbl
# CanESM5_1pctCO2-bgc_tran
# CanESM5_1pctCO2-bgc_rlds
# CanESM5_1pctCO2-bgc_rsds
# CanESM5_1pctCO2-bgc_rlus
# CanESM5_1pctCO2-bgc_rsus
# CanESM5_1pctCO2-bgc_hfls
# CanESM5_1pctCO2-bgc_hfss
# CanESM5_1pctCO2-bgc_rsuscs
# CanESM5_1pctCO2-bgc_rldscs
# CanESM5_1pctCO2-bgc_rsdt
# CanESM5_1pctCO2-bgc_rlut
# CanESM5_1pctCO2-bgc_rsut
# CanESM5_1pctCO2-bgc_tas
# CanESM5_1pctCO2-rad_hurs
# CanESM5_1pctCO2-rad_huss
# CanESM5_1pctCO2-rad_clt
# CanESM5_1pctCO2-rad_lai
# CanESM5_1pctCO2-rad_gpp
# CanESM5_1pctCO2-rad_evspsbl
# CanESM5_1pctCO2-rad_tran
# CanESM5_1pctCO2-rad_pr
# CanESM5_1pctCO2-rad_rlds
# CanESM5_1pctCO2-rad_rsds
# CanESM5_1pctCO2-rad_rlus
# CanESM5_1pctCO2-rad_rsus
# CanESM5_1pctCO2-rad_hfls
# CanESM5_1pctCO2-rad_hfss
# CanESM5_1pctCO2-rad_rsdscs
# CanESM5_1pctCO2-rad_rsuscs
# CanESM5_1pctCO2-rad_rldscs
# CanESM5_1pctCO2-rad_rsdt
# CanESM5_1pctCO2-rad_rlut
# CanESM5_1pctCO2-rad_rsut
# CanESM5_1pctCO2-rad_tas
# CanESM5_1pctCO2_hurs
# CanESM5_1pctCO2_huss
# CanESM5_1pctCO2_clt
# CanESM5_1pctCO2_lai
# CanESM5_1pctCO2_gpp
# CanESM5_1pctCO2_evspsbl
# CanESM5_1pctCO2_tran
# CanESM5_1pctCO2_pr
# CanESM5_1pctCO2_rlds
# CanESM5_1pctCO2_rsds
# CanESM5_1pctCO2_rlus
# CanESM5_1pctCO2_rsus
# CanESM5_1pctCO2_hfls
# CanESM5_1pctCO2_hfss
# CanESM5_1pctCO2_rsdscs
# CanESM5_1pctCO2_rldscs
# CanESM5_1pctCO2_rsdt
# CanESM5_1pctCO2_rlut
# CanESM5_1pctCO2_rsut
# CanESM5_1pctCO2_tas
# CanESM5_piControl_huss
# CanESM5_piControl_clt
# CanESM5_piControl_lai
# CanESM5_piControl_evspsbl
# CanESM5_piControl_rlds
# CanESM5_piControl_rlus
# CanESM5_piControl_hfls
# CanESM5_piControl_rldscs
# CanESM5_piControl_rlut
# CanESM5_piControl_tas
# CESM2_areacella
# CESM2_sftlf
# CESM2_sftgif
# CESM2_1pctCO2-bgc_hurs
# CESM2_1pctCO2-bgc_huss
# CESM2_1pctCO2-bgc_lai
# CESM2_1pctCO2-bgc_gpp
# CESM2_1pctCO2-bgc_evspsbl
# CESM2_1pctCO2-bgc_tran
# CESM2_1pctCO2-bgc_pr
# CESM2_1pctCO2-bgc_rlds
# CESM2_1pctCO2-bgc_rsds
# CESM2_1pctCO2-bgc_rlus
# CESM2_1pctCO2-bgc_rsus
# CESM2_1pctCO2-bgc_hfls
# CESM2_1pctCO2-bgc_hfss
# CESM2_1pctCO2-bgc_rsdscs
# CESM2_1pctCO2-bgc_rsuscs
# CESM2_1pctCO2-bgc_rldscs
# CESM2_1pctCO2-bgc_rsdt
# CESM2_1pctCO2-bgc_rlut
# CESM2_1pctCO2-bgc_rsut
# CESM2_1pctCO2-bgc_tas
# CESM2_1pctCO2-bgc_ts
# CESM2_1pctCO2-bgc_vegHeight
# CESM2_1pctCO2-bgc_ps
# CESM2_1pctCO2-rad_hurs
# CESM2_1pctCO2-rad_clt
# CESM2_1pctCO2-rad_lai
# CESM2_1pctCO2-rad_gpp
# CESM2_1pctCO2-rad_evspsbl
# CESM2_1pctCO2-rad_tran
# CESM2_1pctCO2-rad_rlds
# CESM2_1pctCO2-rad_rsds
# CESM2_1pctCO2-rad_rlus
# CESM2_1pctCO2-rad_rsus
# CESM2_1pctCO2-rad_hfls
# CESM2_1pctCO2-rad_hfss
# CESM2_1pctCO2-rad_rsdscs
# CESM2_1pctCO2-rad_rsuscs
# CESM2_1pctCO2-rad_rldscs
# CESM2_1pctCO2-rad_rsdt
# CESM2_1pctCO2-rad_rlut
# CESM2_1pctCO2-rad_rsut
# CESM2_1pctCO2-rad_tas
# CESM2_1pctCO2-rad_ts
# CESM2_1pctCO2_hurs
# CESM2_1pctCO2_huss
# CESM2_1pctCO2_clt
# CESM2_1pctCO2_lai
# CESM2_1pctCO2_gpp
# CESM2_1pctCO2_evspsbl
# CESM2_1pctCO2_tran
# CESM2_1pctCO2_pr
# CESM2_1pctCO2_rlds
# CESM2_1pctCO2_rsds
# CESM2_1pctCO2_rlus
# CESM2_1pctCO2_rsus
# CESM2_1pctCO2_hfls
# CESM2_1pctCO2_hfss
# CESM2_1pctCO2_rsdscs
# CESM2_1pctCO2_rsuscs
# CESM2_1pctCO2_rldscs
# CESM2_1pctCO2_rsdt
# CESM2_1pctCO2_rlut
# CESM2_1pctCO2_rsut
# CESM2_1pctCO2_tas
# CESM2_1pctCO2_ts
# CESM2_1pctCO2_vegHeight
# CESM2_piControl_huss
# CESM2_piControl_lai
# CESM2_piControl_rlds
# CESM2_piControl_rsds
# CESM2_piControl_rlus
# CESM2_piControl_rsus
# CESM2_piControl_hfls
# CESM2_piControl_hfss
# CESM2_piControl_rsut
# CESM2_piControl_tas
# CESM2_piControl_ts
# CESM2_piControl_vegHeight
# CESM2_piControl_ps
# CNRM-ESM2-1_areacella
# CNRM-ESM2-1_sftlf
# CNRM-ESM2-1_sftgif
# CNRM-ESM2-1_1pctCO2-bgc_hurs
# CNRM-ESM2-1_1pctCO2-bgc_huss
# CNRM-ESM2-1_1pctCO2-bgc_lai
# CNRM-ESM2-1_1pctCO2-bgc_gpp
# CNRM-ESM2-1_1pctCO2-bgc_evspsbl
# CNRM-ESM2-1_1pctCO2-bgc_evspsblpot
# CNRM-ESM2-1_1pctCO2-bgc_tran
# CNRM-ESM2-1_1pctCO2-bgc_pr
# CNRM-ESM2-1_1pctCO2-bgc_rlds
# CNRM-ESM2-1_1pctCO2-bgc_rsds
# CNRM-ESM2-1_1pctCO2-bgc_rlus
# CNRM-ESM2-1_1pctCO2-bgc_rsus
# CNRM-ESM2-1_1pctCO2-bgc_hfls
# CNRM-ESM2-1_1pctCO2-bgc_hfss
# CNRM-ESM2-1_1pctCO2-bgc_rsdt
# CNRM-ESM2-1_1pctCO2-bgc_rlut
# CNRM-ESM2-1_1pctCO2-bgc_rsut
# CNRM-ESM2-1_1pctCO2-bgc_tas
# CNRM-ESM2-1_1pctCO2-rad_hurs
# CNRM-ESM2-1_1pctCO2-rad_huss
# CNRM-ESM2-1_1pctCO2-rad_clt
# CNRM-ESM2-1_1pctCO2-rad_lai
# CNRM-ESM2-1_1pctCO2-rad_gpp
# CNRM-ESM2-1_1pctCO2-rad_evspsbl
# CNRM-ESM2-1_1pctCO2-rad_tran
# CNRM-ESM2-1_1pctCO2-rad_pr
# CNRM-ESM2-1_1pctCO2-rad_rlds
# CNRM-ESM2-1_1pctCO2-rad_rsds
# CNRM-ESM2-1_1pctCO2-rad_rlus
# CNRM-ESM2-1_1pctCO2-rad_rsus
# CNRM-ESM2-1_1pctCO2-rad_hfls
# CNRM-ESM2-1_1pctCO2-rad_hfss
# CNRM-ESM2-1_1pctCO2-rad_rsdscs
# CNRM-ESM2-1_1pctCO2-rad_rsuscs
# CNRM-ESM2-1_1pctCO2-rad_rldscs
# CNRM-ESM2-1_1pctCO2-rad_rsdt
# CNRM-ESM2-1_1pctCO2-rad_rlut
# CNRM-ESM2-1_1pctCO2-rad_rsut
# CNRM-ESM2-1_1pctCO2-rad_tas
# CNRM-ESM2-1_1pctCO2_hurs
# CNRM-ESM2-1_1pctCO2_huss
# CNRM-ESM2-1_1pctCO2_clt
# CNRM-ESM2-1_1pctCO2_lai
# CNRM-ESM2-1_1pctCO2_evspsbl
# CNRM-ESM2-1_1pctCO2_evspsblpot
# CNRM-ESM2-1_1pctCO2_tran
# CNRM-ESM2-1_1pctCO2_pr
# CNRM-ESM2-1_1pctCO2_rlds
# CNRM-ESM2-1_1pctCO2_rsds
# CNRM-ESM2-1_1pctCO2_rlus
# CNRM-ESM2-1_1pctCO2_rsus
# CNRM-ESM2-1_1pctCO2_hfls
# CNRM-ESM2-1_1pctCO2_hfss
# CNRM-ESM2-1_1pctCO2_rsdscs
# CNRM-ESM2-1_1pctCO2_rsuscs
# CNRM-ESM2-1_1pctCO2_rldscs
# CNRM-ESM2-1_1pctCO2_rsdt
# CNRM-ESM2-1_1pctCO2_rlut
# CNRM-ESM2-1_1pctCO2_rsut
# CNRM-ESM2-1_1pctCO2_tas
# CNRM-ESM2-1_piControl_lai
# CNRM-ESM2-1_piControl_evspsbl
# CNRM-ESM2-1_piControl_tran
# CNRM-ESM2-1_piControl_hfls
# CNRM-ESM2-1_piControl_rsut
# CNRM-ESM2-1_piControl_tas
# GFDL-ESM4_areacella
# GFDL-ESM4_sftlf
# GFDL-ESM4_sftgif
# GFDL-ESM4_1pctCO2-bgc_hurs
# GFDL-ESM4_1pctCO2-bgc_lai
# GFDL-ESM4_1pctCO2-bgc_gpp
# GFDL-ESM4_1pctCO2-bgc_tran
# GFDL-ESM4_1pctCO2-bgc_rlds
# GFDL-ESM4_1pctCO2-bgc_tas
# GFDL-ESM4_1pctCO2-rad_hurs
# GFDL-ESM4_1pctCO2-rad_huss
# GFDL-ESM4_1pctCO2-rad_clt
# GFDL-ESM4_1pctCO2-rad_evspsbl
# GFDL-ESM4_1pctCO2-rad_pr
# GFDL-ESM4_1pctCO2-rad_rlds
# GFDL-ESM4_1pctCO2-rad_rsds
# GFDL-ESM4_1pctCO2-rad_rlus
# GFDL-ESM4_1pctCO2-rad_rsus
# GFDL-ESM4_1pctCO2-rad_hfls
# GFDL-ESM4_1pctCO2-rad_hfss
# GFDL-ESM4_1pctCO2-rad_rsdt
# GFDL-ESM4_1pctCO2-rad_rlut
# GFDL-ESM4_1pctCO2-rad_rsut
# GFDL-ESM4_1pctCO2-rad_tas
# GFDL-ESM4_1pctCO2-rad_ts
# GFDL-ESM4_1pctCO2-rad_ps
# GFDL-ESM4_1pctCO2_hurs
# GFDL-ESM4_1pctCO2_clt
# GFDL-ESM4_1pctCO2_lai
# GFDL-ESM4_1pctCO2_gpp
# GFDL-ESM4_1pctCO2_evspsbl
# GFDL-ESM4_1pctCO2_tran
# GFDL-ESM4_1pctCO2_rlds
# GFDL-ESM4_1pctCO2_rsds
# GFDL-ESM4_1pctCO2_rlus
# GFDL-ESM4_1pctCO2_rsus
# GFDL-ESM4_1pctCO2_hfls
# GFDL-ESM4_1pctCO2_hfss
# GFDL-ESM4_1pctCO2_rsdscs
# GFDL-ESM4_1pctCO2_rsuscs
# GFDL-ESM4_1pctCO2_rldscs
# GFDL-ESM4_1pctCO2_rsdt
# GFDL-ESM4_1pctCO2_rlut
# GFDL-ESM4_1pctCO2_rsut
# GFDL-ESM4_1pctCO2_tas
# GFDL-ESM4_piControl_lai
# GFDL-ESM4_piControl_tran
# GFDL-ESM4_piControl_hfls
# GFDL-ESM4_piControl_tas
# GISS-E2-1-G_areacella
# GISS-E2-1-G_sftlf
# GISS-E2-1-G_sftgif
# GISS-E2-1-G_1pctCO2-bgc_hurs
# GISS-E2-1-G_1pctCO2-bgc_lai
# GISS-E2-1-G_1pctCO2-bgc_gpp
# GISS-E2-1-G_1pctCO2-bgc_evspsbl
# GISS-E2-1-G_1pctCO2-bgc_tran
# GISS-E2-1-G_1pctCO2-bgc_rlds
# GISS-E2-1-G_1pctCO2-bgc_rsds
# GISS-E2-1-G_1pctCO2-bgc_rlus
# GISS-E2-1-G_1pctCO2-bgc_rsus
# GISS-E2-1-G_1pctCO2-bgc_hfls
# GISS-E2-1-G_1pctCO2-bgc_hfss
# GISS-E2-1-G_1pctCO2-bgc_rsdt
# GISS-E2-1-G_1pctCO2-bgc_rlut
# GISS-E2-1-G_1pctCO2-bgc_rsut
# GISS-E2-1-G_1pctCO2-bgc_tas
# GISS-E2-1-G_1pctCO2-bgc_ts
# GISS-E2-1-G_1pctCO2-bgc_ps
# GISS-E2-1-G_1pctCO2-rad_clt
# GISS-E2-1-G_1pctCO2-rad_lai
# GISS-E2-1-G_1pctCO2-rad_evspsbl
# GISS-E2-1-G_1pctCO2-rad_tran
# GISS-E2-1-G_1pctCO2-rad_rlds
# GISS-E2-1-G_1pctCO2-rad_rsds
# GISS-E2-1-G_1pctCO2-rad_rlus
# GISS-E2-1-G_1pctCO2-rad_rsus
# GISS-E2-1-G_1pctCO2-rad_hfls
# GISS-E2-1-G_1pctCO2-rad_hfss
# GISS-E2-1-G_1pctCO2-rad_rsdscs
# GISS-E2-1-G_1pctCO2-rad_rsuscs
# GISS-E2-1-G_1pctCO2-rad_rldscs
# GISS-E2-1-G_1pctCO2-rad_tas
# GISS-E2-1-G_1pctCO2-rad_ts
# GISS-E2-1-G_1pctCO2-rad_ps
# GISS-E2-1-G_1pctCO2_hurs
# GISS-E2-1-G_1pctCO2_clt
# GISS-E2-1-G_1pctCO2_lai
# GISS-E2-1-G_1pctCO2_gpp
# GISS-E2-1-G_1pctCO2_evspsbl
# GISS-E2-1-G_1pctCO2_tran
# GISS-E2-1-G_1pctCO2_rlds
# GISS-E2-1-G_1pctCO2_rsds
# GISS-E2-1-G_1pctCO2_rlus
# GISS-E2-1-G_1pctCO2_hfls
# GISS-E2-1-G_1pctCO2_rsdscs
# GISS-E2-1-G_1pctCO2_rsuscs
# GISS-E2-1-G_1pctCO2_rldscs
# GISS-E2-1-G_1pctCO2_rsdt
# GISS-E2-1-G_1pctCO2_rlut
# GISS-E2-1-G_1pctCO2_rsut
# GISS-E2-1-G_1pctCO2_tas
# GISS-E2-1-G_1pctCO2_ts
# GISS-E2-1-G_1pctCO2_ps
# GISS-E2-1-G_piControl_tas
# IPSL-CM6A-LR_areacella
# IPSL-CM6A-LR_sftlf
# IPSL-CM6A-LR_sftgif
# IPSL-CM6A-LR_1pctCO2-bgc_hurs
# IPSL-CM6A-LR_1pctCO2-bgc_huss
# IPSL-CM6A-LR_1pctCO2-bgc_lai
# IPSL-CM6A-LR_1pctCO2-bgc_gpp
# IPSL-CM6A-LR_1pctCO2-bgc_evspsbl
# IPSL-CM6A-LR_1pctCO2-bgc_tran
# IPSL-CM6A-LR_1pctCO2-bgc_rlds
# IPSL-CM6A-LR_1pctCO2-bgc_rsds
# IPSL-CM6A-LR_1pctCO2-bgc_rlus
# IPSL-CM6A-LR_1pctCO2-bgc_rsus
# IPSL-CM6A-LR_1pctCO2-bgc_hfls
# IPSL-CM6A-LR_1pctCO2-bgc_hfss
# IPSL-CM6A-LR_1pctCO2-bgc_rsdt
# IPSL-CM6A-LR_1pctCO2-bgc_rlut
# IPSL-CM6A-LR_1pctCO2-bgc_rsut
# IPSL-CM6A-LR_1pctCO2-bgc_tas
# IPSL-CM6A-LR_1pctCO2-bgc_ts
# IPSL-CM6A-LR_1pctCO2-rad_hurs
# IPSL-CM6A-LR_1pctCO2-rad_huss
# IPSL-CM6A-LR_1pctCO2-rad_clt
# IPSL-CM6A-LR_1pctCO2-rad_lai
# IPSL-CM6A-LR_1pctCO2-rad_gpp
# IPSL-CM6A-LR_1pctCO2-rad_evspsbl
# IPSL-CM6A-LR_1pctCO2-rad_tran
# IPSL-CM6A-LR_1pctCO2-rad_rlds
# IPSL-CM6A-LR_1pctCO2-rad_rsds
# IPSL-CM6A-LR_1pctCO2-rad_rlus
# IPSL-CM6A-LR_1pctCO2-rad_rsus
# IPSL-CM6A-LR_1pctCO2-rad_hfls
# IPSL-CM6A-LR_1pctCO2-rad_hfss
# IPSL-CM6A-LR_1pctCO2-rad_rsdscs
# IPSL-CM6A-LR_1pctCO2-rad_rsuscs
# IPSL-CM6A-LR_1pctCO2-rad_rldscs
# IPSL-CM6A-LR_1pctCO2-rad_rsdt
# IPSL-CM6A-LR_1pctCO2-rad_rlut
# IPSL-CM6A-LR_1pctCO2-rad_rsut
# IPSL-CM6A-LR_1pctCO2-rad_tas
# IPSL-CM6A-LR_1pctCO2-rad_ts
# IPSL-CM6A-LR_1pctCO2_hurs
# IPSL-CM6A-LR_1pctCO2_huss
# IPSL-CM6A-LR_1pctCO2_clt
# IPSL-CM6A-LR_1pctCO2_lai
# IPSL-CM6A-LR_1pctCO2_gpp
# IPSL-CM6A-LR_1pctCO2_evspsbl
# IPSL-CM6A-LR_1pctCO2_tran
# IPSL-CM6A-LR_1pctCO2_rlds
# IPSL-CM6A-LR_1pctCO2_rsds
# IPSL-CM6A-LR_1pctCO2_rlus
# IPSL-CM6A-LR_1pctCO2_rsus
# IPSL-CM6A-LR_1pctCO2_hfls
# IPSL-CM6A-LR_1pctCO2_hfss
# IPSL-CM6A-LR_1pctCO2_rsdscs
# IPSL-CM6A-LR_1pctCO2_rsuscs
# IPSL-CM6A-LR_1pctCO2_rldscs
# IPSL-CM6A-LR_1pctCO2_rlut
# IPSL-CM6A-LR_1pctCO2_rsut
# IPSL-CM6A-LR_1pctCO2_tas
# IPSL-CM6A-LR_piControl_hurs
# IPSL-CM6A-LR_piControl_huss
# IPSL-CM6A-LR_piControl_lai
# IPSL-CM6A-LR_piControl_gpp
# IPSL-CM6A-LR_piControl_evspsbl
# IPSL-CM6A-LR_piControl_tran
# IPSL-CM6A-LR_piControl_rlds
# IPSL-CM6A-LR_piControl_rsds
# IPSL-CM6A-LR_piControl_rlus
# IPSL-CM6A-LR_piControl_rsus
# IPSL-CM6A-LR_piControl_hfls
# IPSL-CM6A-LR_piControl_hfss
# IPSL-CM6A-LR_piControl_rsdt
# IPSL-CM6A-LR_piControl_rlut
# IPSL-CM6A-LR_piControl_rsut
# IPSL-CM6A-LR_piControl_tas
# IPSL-CM6A-LR_piControl_ts
# MIROC-ES2L_areacella
# MIROC-ES2L_sftlf
# MIROC-ES2L_sftgif
# MIROC-ES2L_1pctCO2-bgc_hurs
# MIROC-ES2L_1pctCO2-bgc_lai
# MIROC-ES2L_1pctCO2-bgc_gpp
# MIROC-ES2L_1pctCO2-bgc_evspsbl
# MIROC-ES2L_1pctCO2-bgc_tran
# MIROC-ES2L_1pctCO2-bgc_rlds
# MIROC-ES2L_1pctCO2-bgc_rsds
# MIROC-ES2L_1pctCO2-bgc_rlus
# MIROC-ES2L_1pctCO2-bgc_rsus
# MIROC-ES2L_1pctCO2-bgc_hfls
# MIROC-ES2L_1pctCO2-bgc_hfss
# MIROC-ES2L_1pctCO2-bgc_rsdt
# MIROC-ES2L_1pctCO2-bgc_rlut
# MIROC-ES2L_1pctCO2-bgc_rsut
# MIROC-ES2L_1pctCO2-bgc_tas
# MIROC-ES2L_1pctCO2-rad_hurs
# MIROC-ES2L_1pctCO2-rad_clt
# MIROC-ES2L_1pctCO2-rad_lai
# MIROC-ES2L_1pctCO2-rad_gpp
# MIROC-ES2L_1pctCO2-rad_evspsbl
# MIROC-ES2L_1pctCO2-rad_tran
# MIROC-ES2L_1pctCO2-rad_rlds
# MIROC-ES2L_1pctCO2-rad_rsds
# MIROC-ES2L_1pctCO2-rad_rlus
# MIROC-ES2L_1pctCO2-rad_rsus
# MIROC-ES2L_1pctCO2-rad_hfls
# MIROC-ES2L_1pctCO2-rad_hfss
# MIROC-ES2L_1pctCO2-rad_rsdscs
# MIROC-ES2L_1pctCO2-rad_rsuscs
# MIROC-ES2L_1pctCO2-rad_rldscs
# MIROC-ES2L_1pctCO2-rad_rsdt
# MIROC-ES2L_1pctCO2-rad_rlut
# MIROC-ES2L_1pctCO2-rad_rsut
# MIROC-ES2L_1pctCO2-rad_tas
# MIROC-ES2L_1pctCO2_hurs
# MIROC-ES2L_1pctCO2_clt
# MIROC-ES2L_1pctCO2_lai
# MIROC-ES2L_1pctCO2_gpp
# MIROC-ES2L_1pctCO2_evspsbl
# MIROC-ES2L_1pctCO2_tran
# MIROC-ES2L_1pctCO2_rlds
# MIROC-ES2L_1pctCO2_rsds
# MIROC-ES2L_1pctCO2_rlus
# MIROC-ES2L_1pctCO2_rsus
# MIROC-ES2L_1pctCO2_hfls
# MIROC-ES2L_1pctCO2_hfss
# MIROC-ES2L_1pctCO2_rsdscs
# MIROC-ES2L_1pctCO2_rsuscs
# MIROC-ES2L_1pctCO2_rldscs
# MIROC-ES2L_1pctCO2_rsdt
# MIROC-ES2L_1pctCO2_rlut
# MIROC-ES2L_1pctCO2_rsut
# MIROC-ES2L_1pctCO2_tas
# MIROC-ES2L_piControl_lai
# MIROC-ES2L_piControl_tas
# MRI-ESM2-0_areacella
# MRI-ESM2-0_sftlf
# MRI-ESM2-0_sftgif
# MRI-ESM2-0_1pctCO2-bgc_hurs
# MRI-ESM2-0_1pctCO2-bgc_huss
# MRI-ESM2-0_1pctCO2-bgc_clt
# MRI-ESM2-0_1pctCO2-bgc_evspsbl
# MRI-ESM2-0_1pctCO2-bgc_rlds
# MRI-ESM2-0_1pctCO2-bgc_rsds
# MRI-ESM2-0_1pctCO2-bgc_rlus
# MRI-ESM2-0_1pctCO2-bgc_rsus
# MRI-ESM2-0_1pctCO2-bgc_hfls
# MRI-ESM2-0_1pctCO2-bgc_hfss
# MRI-ESM2-0_1pctCO2-bgc_rsdscs
# MRI-ESM2-0_1pctCO2-bgc_rsuscs
# MRI-ESM2-0_1pctCO2-bgc_rldscs
# MRI-ESM2-0_1pctCO2-bgc_rsdt
# MRI-ESM2-0_1pctCO2-bgc_rlut
# MRI-ESM2-0_1pctCO2-bgc_rsut
# MRI-ESM2-0_1pctCO2-bgc_tas
# MRI-ESM2-0_1pctCO2-bgc_ts
# MRI-ESM2-0_1pctCO2-rad_hurs
# MRI-ESM2-0_1pctCO2-rad_clt
# MRI-ESM2-0_1pctCO2-rad_evspsbl
# MRI-ESM2-0_1pctCO2-rad_rsds
# MRI-ESM2-0_1pctCO2-rad_rlus
# MRI-ESM2-0_1pctCO2-rad_rsus
# MRI-ESM2-0_1pctCO2-rad_hfls
# MRI-ESM2-0_1pctCO2-rad_hfss
# MRI-ESM2-0_1pctCO2-rad_rsdscs
# MRI-ESM2-0_1pctCO2-rad_rsuscs
# MRI-ESM2-0_1pctCO2-rad_rldscs
# MRI-ESM2-0_1pctCO2-rad_rsdt
# MRI-ESM2-0_1pctCO2-rad_rlut
# MRI-ESM2-0_1pctCO2-rad_rsut
# MRI-ESM2-0_1pctCO2-rad_tas
# MRI-ESM2-0_1pctCO2-rad_ts
# MRI-ESM2-0_1pctCO2_hurs
# MRI-ESM2-0_1pctCO2_clt
# MRI-ESM2-0_1pctCO2_evspsbl
# MRI-ESM2-0_1pctCO2_rlds
# MRI-ESM2-0_1pctCO2_rsds
# MRI-ESM2-0_1pctCO2_rlus
# MRI-ESM2-0_1pctCO2_rsus
# MRI-ESM2-0_1pctCO2_hfls
# MRI-ESM2-0_1pctCO2_hfss
# MRI-ESM2-0_1pctCO2_rsdscs
# MRI-ESM2-0_1pctCO2_rsuscs
# MRI-ESM2-0_1pctCO2_rldscs
# MRI-ESM2-0_1pctCO2_rsdt
# MRI-ESM2-0_1pctCO2_rlut
# MRI-ESM2-0_1pctCO2_rsut
# MRI-ESM2-0_1pctCO2_tas
# MRI-ESM2-0_1pctCO2_ts
# MRI-ESM2-0_piControl_tas
# UKESM1-0-LL_areacella
# UKESM1-0-LL_sftlf
# UKESM1-0-LL_sftgif
# UKESM1-0-LL_1pctCO2-bgc_hurs
# UKESM1-0-LL_1pctCO2-bgc_lai
# UKESM1-0-LL_1pctCO2-bgc_gpp
# UKESM1-0-LL_1pctCO2-bgc_evspsbl
# UKESM1-0-LL_1pctCO2-bgc_tran
# UKESM1-0-LL_1pctCO2-bgc_rlds
# UKESM1-0-LL_1pctCO2-bgc_rsds
# UKESM1-0-LL_1pctCO2-bgc_rlus
# UKESM1-0-LL_1pctCO2-bgc_rsus
# UKESM1-0-LL_1pctCO2-bgc_hfls
# UKESM1-0-LL_1pctCO2-bgc_hfss
# UKESM1-0-LL_1pctCO2-bgc_rsdt
# UKESM1-0-LL_1pctCO2-bgc_rlut
# UKESM1-0-LL_1pctCO2-bgc_rsut
# UKESM1-0-LL_1pctCO2-bgc_tas
# UKESM1-0-LL_1pctCO2-rad_hurs
# UKESM1-0-LL_1pctCO2-rad_clt
# UKESM1-0-LL_1pctCO2-rad_lai
# UKESM1-0-LL_1pctCO2-rad_gpp
# UKESM1-0-LL_1pctCO2-rad_evspsbl
# UKESM1-0-LL_1pctCO2-rad_tran
# UKESM1-0-LL_1pctCO2-rad_rlds
# UKESM1-0-LL_1pctCO2-rad_rsds
# UKESM1-0-LL_1pctCO2-rad_rlus
# UKESM1-0-LL_1pctCO2-rad_rsus
# UKESM1-0-LL_1pctCO2-rad_hfls
# UKESM1-0-LL_1pctCO2-rad_hfss
# UKESM1-0-LL_1pctCO2-rad_rsdscs
# UKESM1-0-LL_1pctCO2-rad_rsuscs
# UKESM1-0-LL_1pctCO2-rad_rldscs
# UKESM1-0-LL_1pctCO2-rad_rsdt
# UKESM1-0-LL_1pctCO2-rad_rlut
# UKESM1-0-LL_1pctCO2-rad_rsut
# UKESM1-0-LL_1pctCO2-rad_tas
# UKESM1-0-LL_1pctCO2_hurs
# UKESM1-0-LL_1pctCO2_clt
# UKESM1-0-LL_1pctCO2_lai
# UKESM1-0-LL_1pctCO2_gpp
# UKESM1-0-LL_1pctCO2_evspsbl
# UKESM1-0-LL_1pctCO2_tran
# UKESM1-0-LL_1pctCO2_rlds
# UKESM1-0-LL_1pctCO2_rsds
# UKESM1-0-LL_1pctCO2_rlus
# UKESM1-0-LL_1pctCO2_rsus
# UKESM1-0-LL_1pctCO2_hfls
# UKESM1-0-LL_1pctCO2_hfss
# UKESM1-0-LL_1pctCO2_rsdscs
# UKESM1-0-LL_1pctCO2_rsuscs
# UKESM1-0-LL_1pctCO2_rldscs
# UKESM1-0-LL_1pctCO2_rsdt
# UKESM1-0-LL_1pctCO2_rlut
# UKESM1-0-LL_1pctCO2_rsut
# UKESM1-0-LL_1pctCO2_tas
# UKESM1-0-LL_piControl_evspsbl
# UKESM1-0-LL_piControl_tran
# UKESM1-0-LL_piControl_hfls
# UKESM1-0-LL_piControl_rsdt
# UKESM1-0-LL_piControl_rlut
# UKESM1-0-LL_piControl_rsut
# UKESM1-0-LL_piControl_tas
# ACCESS-ESM1-5_areacella
# ACCESS-ESM1-5_sftlf
# ACCESS-ESM1-5_sftgif
# ACCESS-ESM1-5_1pctCO2-bgc_tas
# ACCESS-ESM1-5_1pctCO2-rad_hurs
# ACCESS-ESM1-5_1pctCO2-rad_huss
# ACCESS-ESM1-5_1pctCO2-rad_clt
# ACCESS-ESM1-5_1pctCO2-rad_lai
# ACCESS-ESM1-5_1pctCO2-rad_evspsbl
# ACCESS-ESM1-5_1pctCO2-rad_rlds
# ACCESS-ESM1-5_1pctCO2-rad_rsds
# ACCESS-ESM1-5_1pctCO2-rad_rlus
# ACCESS-ESM1-5_1pctCO2-rad_rsus
# ACCESS-ESM1-5_1pctCO2-rad_hfls
# ACCESS-ESM1-5_1pctCO2-rad_hfss
# ACCESS-ESM1-5_1pctCO2-rad_rsdscs
# ACCESS-ESM1-5_1pctCO2-rad_rldscs
# ACCESS-ESM1-5_1pctCO2-rad_tas
# ACCESS-ESM1-5_1pctCO2-rad_ts
# ACCESS-ESM1-5_1pctCO2_clt
# ACCESS-ESM1-5_1pctCO2_lai
# ACCESS-ESM1-5_1pctCO2_evspsbl
# ACCESS-ESM1-5_1pctCO2_rlds
# ACCESS-ESM1-5_1pctCO2_rsds
# ACCESS-ESM1-5_1pctCO2_rlus
# ACCESS-ESM1-5_1pctCO2_rsus
# ACCESS-ESM1-5_1pctCO2_hfls
# ACCESS-ESM1-5_1pctCO2_hfss
# ACCESS-ESM1-5_1pctCO2_rsdscs
# ACCESS-ESM1-5_1pctCO2_rldscs
# ACCESS-ESM1-5_1pctCO2_tas
# ACCESS-ESM1-5_piControl_tas
# NorESM2-LM_areacella
# NorESM2-LM_sftlf
# NorESM2-LM_sftgif
# NorESM2-LM_1pctCO2-rad_clt
# NorESM2-LM_1pctCO2-rad_lai
# NorESM2-LM_1pctCO2-rad_gpp
# NorESM2-LM_1pctCO2-rad_evspsbl
# NorESM2-LM_1pctCO2-rad_tran
# NorESM2-LM_1pctCO2-rad_rlds
# NorESM2-LM_1pctCO2-rad_rsds
# NorESM2-LM_1pctCO2-rad_rlus
# NorESM2-LM_1pctCO2-rad_rsus
# NorESM2-LM_1pctCO2-rad_hfls
# NorESM2-LM_1pctCO2-rad_hfss
# NorESM2-LM_1pctCO2-rad_rsdscs
# NorESM2-LM_1pctCO2-rad_tas
# NorESM2-LM_1pctCO2_clt
# NorESM2-LM_1pctCO2_lai
# NorESM2-LM_1pctCO2_gpp
# NorESM2-LM_1pctCO2_evspsbl
# NorESM2-LM_1pctCO2_tran
# NorESM2-LM_1pctCO2_rlds
# NorESM2-LM_1pctCO2_rsds
# NorESM2-LM_1pctCO2_rlus
# NorESM2-LM_1pctCO2_rsus
# NorESM2-LM_1pctCO2_hfls
# NorESM2-LM_1pctCO2_hfss
# NorESM2-LM_1pctCO2_rsdscs
# NorESM2-LM_1pctCO2_tas
# NorESM2-LM_piControl_tas
# MPI-ESM1-2-LR_areacella
# MPI-ESM1-2-LR_sftlf
# MPI-ESM1-2-LR_sftgif
# MPI-ESM1-2-LR_1pctCO2-bgc_tas
# MPI-ESM1-2-LR_1pctCO2-rad_clt
# MPI-ESM1-2-LR_1pctCO2-rad_lai
# MPI-ESM1-2-LR_1pctCO2-rad_evspsbl
# MPI-ESM1-2-LR_1pctCO2-rad_rlds
# MPI-ESM1-2-LR_1pctCO2-rad_rsds
# MPI-ESM1-2-LR_1pctCO2-rad_rlus
# MPI-ESM1-2-LR_1pctCO2-rad_rsus
# MPI-ESM1-2-LR_1pctCO2-rad_hfls
# MPI-ESM1-2-LR_1pctCO2-rad_hfss
# MPI-ESM1-2-LR_1pctCO2-rad_rsdscs
# MPI-ESM1-2-LR_1pctCO2-rad_rldscs
# MPI-ESM1-2-LR_1pctCO2-rad_tas
# MPI-ESM1-2-LR_1pctCO2_clt
# MPI-ESM1-2-LR_1pctCO2_lai
# MPI-ESM1-2-LR_1pctCO2_evspsbl
# MPI-ESM1-2-LR_1pctCO2_rlds
# MPI-ESM1-2-LR_1pctCO2_rsds
# MPI-ESM1-2-LR_1pctCO2_rlus
# MPI-ESM1-2-LR_1pctCO2_rsus
# MPI-ESM1-2-LR_1pctCO2_hfls
# MPI-ESM1-2-LR_1pctCO2_hfss
# MPI-ESM1-2-LR_1pctCO2_rsdscs
# MPI-ESM1-2-LR_1pctCO2_rldscs
# MPI-ESM1-2-LR_1pctCO2_tas
# MPI-ESM1-2-LR_piControl_tas
# MPI-ESM-LR_areacella
# MPI-ESM-LR_sftlf
# MPI-ESM-LR_sftgif
# MPI-ESM-LR_1pctCO2-bgc_hfls
# MPI-ESM-LR_1pctCO2-bgc_hfss
# MPI-ESM-LR_1pctCO2-bgc_ps
# MPI-ESM-LR_1pctCO2-bgc_evspsbl
# MPI-ESM-LR_1pctCO2-bgc_tas
# MPI-ESM-LR_1pctCO2-bgc_ts
# MPI-ESM-LR_1pctCO2-bgc_pr
# MPI-ESM-LR_1pctCO2-bgc_sfcWind
# MPI-ESM-LR_1pctCO2-bgc_tran
# MPI-ESM-LR_1pctCO2-bgc_gpp
# MPI-ESM-LR_1pctCO2-bgc_lai
# MPI-ESM-LR_1pctCO2-bgc_mrro
# MPI-ESM-LR_1pctCO2-bgc_rlds
# MPI-ESM-LR_1pctCO2-bgc_rlus
# MPI-ESM-LR_1pctCO2-bgc_rlut
# MPI-ESM-LR_1pctCO2-bgc_rsds
# MPI-ESM-LR_1pctCO2-bgc_rsdt
# MPI-ESM-LR_1pctCO2-bgc_rsus
# MPI-ESM-LR_1pctCO2-bgc_rsut
# MPI-ESM-LR_1pctCO2-bgc_rldscs
# MPI-ESM-LR_1pctCO2-bgc_rsdscs
# MPI-ESM-LR_1pctCO2-bgc_rsuscs
# MPI-ESM-LR_1pctCO2-bgc_rsutcs
# MPI-ESM-LR_1pctCO2-bgc_rlutcs
# MPI-ESM-LR_1pctCO2_hfls
# MPI-ESM-LR_1pctCO2_hfss
# MPI-ESM-LR_1pctCO2_ps
# MPI-ESM-LR_1pctCO2_evspsbl
# MPI-ESM-LR_1pctCO2_tas
# MPI-ESM-LR_1pctCO2_ts
# MPI-ESM-LR_1pctCO2_pr
# MPI-ESM-LR_1pctCO2_sfcWind
# MPI-ESM-LR_1pctCO2_tran
# MPI-ESM-LR_1pctCO2_gpp
# MPI-ESM-LR_1pctCO2_lai
# MPI-ESM-LR_1pctCO2_mrro
# MPI-ESM-LR_1pctCO2_rlds
# MPI-ESM-LR_1pctCO2_rlus
# MPI-ESM-LR_1pctCO2_rlut
# MPI-ESM-LR_1pctCO2_rsds
# MPI-ESM-LR_1pctCO2_rsdt
# MPI-ESM-LR_1pctCO2_rsus
# MPI-ESM-LR_1pctCO2_rsut
# MPI-ESM-LR_1pctCO2_rldscs
# MPI-ESM-LR_1pctCO2_rsdscs
# MPI-ESM-LR_1pctCO2_rsutcs
# MPI-ESM-LR_1pctCO2_rlutcs
# MPI-ESM-LR_1pctCO2_clt
# MPI-ESM-LR_1pctCO2-rad_hfls
# MPI-ESM-LR_1pctCO2-rad_hfss
# MPI-ESM-LR_1pctCO2-rad_ps
# MPI-ESM-LR_1pctCO2-rad_evspsbl
# MPI-ESM-LR_1pctCO2-rad_tas
# MPI-ESM-LR_1pctCO2-rad_ts
# MPI-ESM-LR_1pctCO2-rad_pr
# MPI-ESM-LR_1pctCO2-rad_sfcWind
# MPI-ESM-LR_1pctCO2-rad_tran
# MPI-ESM-LR_1pctCO2-rad_gpp
# MPI-ESM-LR_1pctCO2-rad_lai
# MPI-ESM-LR_1pctCO2-rad_mrro
# MPI-ESM-LR_1pctCO2-rad_rlds
# MPI-ESM-LR_1pctCO2-rad_rlus
# MPI-ESM-LR_1pctCO2-rad_rsds
# MPI-ESM-LR_1pctCO2-rad_rsus
# MPI-ESM-LR_1pctCO2-rad_rldscs
# MPI-ESM-LR_1pctCO2-rad_rsdscs
# MPI-ESM-LR_1pctCO2-rad_rsuscs
# MPI-ESM-LR_1pctCO2-rad_rsutcs
# MPI-ESM-LR_1pctCO2-rad_rlutcs
# MPI-ESM-LR_1pctCO2-rad_clt
# MPI-ESM-LR_piControl_tas
# MPI-ESM-LR_piControl_ts
# HadGEM2-ES_areacella
# HadGEM2-ES_sftlf
# HadGEM2-ES_sftgif
# HadGEM2-ES_1pctCO2-bgc_hfls
# HadGEM2-ES_1pctCO2-bgc_hfss
# HadGEM2-ES_1pctCO2-bgc_hurs
# HadGEM2-ES_1pctCO2-bgc_ps
# HadGEM2-ES_1pctCO2-bgc_evspsbl
# HadGEM2-ES_1pctCO2-bgc_tas
# HadGEM2-ES_1pctCO2-bgc_ts
# HadGEM2-ES_1pctCO2-bgc_pr
# HadGEM2-ES_1pctCO2-bgc_sfcWind
# HadGEM2-ES_1pctCO2-bgc_gpp
# HadGEM2-ES_1pctCO2-bgc_lai
# HadGEM2-ES_1pctCO2-bgc_mrso
# HadGEM2-ES_1pctCO2-bgc_rlds
# HadGEM2-ES_1pctCO2-bgc_rlus
# HadGEM2-ES_1pctCO2-bgc_rlut
# HadGEM2-ES_1pctCO2-bgc_rsds
# HadGEM2-ES_1pctCO2-bgc_rsdt
# HadGEM2-ES_1pctCO2-bgc_rsus
# HadGEM2-ES_1pctCO2-bgc_rsut
# HadGEM2-ES_1pctCO2-bgc_rldscs
# HadGEM2-ES_1pctCO2-bgc_rsdscs
# HadGEM2-ES_1pctCO2-bgc_rsuscs
# HadGEM2-ES_1pctCO2-bgc_rsutcs
# HadGEM2-ES_1pctCO2-bgc_rlutcs
# HadGEM2-ES_1pctCO2_hfls
# HadGEM2-ES_1pctCO2_hfss
# HadGEM2-ES_1pctCO2_hurs
# HadGEM2-ES_1pctCO2_huss
# HadGEM2-ES_1pctCO2_ps
# HadGEM2-ES_1pctCO2_evspsbl
# HadGEM2-ES_1pctCO2_tas
# HadGEM2-ES_1pctCO2_ts
# HadGEM2-ES_1pctCO2_pr
# HadGEM2-ES_1pctCO2_sfcWind
# HadGEM2-ES_1pctCO2_gpp
# HadGEM2-ES_1pctCO2_lai
# HadGEM2-ES_1pctCO2_mrso
# HadGEM2-ES_1pctCO2_rlds
# HadGEM2-ES_1pctCO2_rlus
# HadGEM2-ES_1pctCO2_rlut
# HadGEM2-ES_1pctCO2_rsds
# HadGEM2-ES_1pctCO2_rsdt
# HadGEM2-ES_1pctCO2_rsus
# HadGEM2-ES_1pctCO2_rsut
# HadGEM2-ES_1pctCO2_rldscs
# HadGEM2-ES_1pctCO2_rsdscs
# HadGEM2-ES_1pctCO2_rsuscs
# HadGEM2-ES_1pctCO2_rsutcs
# HadGEM2-ES_1pctCO2_rlutcs
# HadGEM2-ES_1pctCO2_clt
# HadGEM2-ES_1pctCO2-rad_hfls
# HadGEM2-ES_1pctCO2-rad_hfss
# HadGEM2-ES_1pctCO2-rad_hurs
# HadGEM2-ES_1pctCO2-rad_huss
# HadGEM2-ES_1pctCO2-rad_ps
# HadGEM2-ES_1pctCO2-rad_evspsbl
# HadGEM2-ES_1pctCO2-rad_tas
# HadGEM2-ES_1pctCO2-rad_ts
# HadGEM2-ES_1pctCO2-rad_pr
# HadGEM2-ES_1pctCO2-rad_sfcWind
# HadGEM2-ES_1pctCO2-rad_gpp
# HadGEM2-ES_1pctCO2-rad_lai
# HadGEM2-ES_1pctCO2-rad_mrso
# HadGEM2-ES_1pctCO2-rad_rlds
# HadGEM2-ES_1pctCO2-rad_rlus
# HadGEM2-ES_1pctCO2-rad_rlut
# HadGEM2-ES_1pctCO2-rad_rsds
# HadGEM2-ES_1pctCO2-rad_rsdt
# HadGEM2-ES_1pctCO2-rad_rsus
# HadGEM2-ES_1pctCO2-rad_rsut
# HadGEM2-ES_1pctCO2-rad_rldscs
# HadGEM2-ES_1pctCO2-rad_rsdscs
# HadGEM2-ES_1pctCO2-rad_rsuscs
# HadGEM2-ES_1pctCO2-rad_rsutcs
# HadGEM2-ES_1pctCO2-rad_rlutcs
# HadGEM2-ES_1pctCO2-rad_clt
# HadGEM2-ES_piControl_tas
# HadGEM2-ES_piControl_ts
# HadGEM2-ES_piControl_rldscs
# HadGEM2-ES_piControl_rsdscs
# HadGEM2-ES_piControl_rsuscs
# HadGEM2-ES_piControl_rsutcs
# HadGEM2-ES_piControl_rlutcs
# HadGEM2-ES_abrupt4xCO2_tas
# HadGEM2-ES_abrupt4xCO2_rlut
# HadGEM2-ES_abrupt4xCO2_rsdt
# HadGEM2-ES_abrupt4xCO2_rsut
# NorESM1-ME_areacella
# NorESM1-ME_sftlf
# NorESM1-ME_sftgif
# NorESM1-ME_1pctCO2-bgc_hfls
# NorESM1-ME_1pctCO2-bgc_hfss
# NorESM1-ME_1pctCO2-bgc_hurs
# NorESM1-ME_1pctCO2-bgc_ps
# NorESM1-ME_1pctCO2-bgc_evspsbl
# NorESM1-ME_1pctCO2-bgc_tas
# NorESM1-ME_1pctCO2-bgc_ts
# NorESM1-ME_1pctCO2-bgc_pr
# NorESM1-ME_1pctCO2-bgc_tran
# NorESM1-ME_1pctCO2-bgc_gpp
# NorESM1-ME_1pctCO2-bgc_lai
# NorESM1-ME_1pctCO2-bgc_mrro
# NorESM1-ME_1pctCO2-bgc_mrso
# NorESM1-ME_1pctCO2-bgc_rlds
# NorESM1-ME_1pctCO2-bgc_rlus
# NorESM1-ME_1pctCO2-bgc_rlut
# NorESM1-ME_1pctCO2-bgc_rsds
# NorESM1-ME_1pctCO2-bgc_rsdt
# NorESM1-ME_1pctCO2-bgc_rsus
# NorESM1-ME_1pctCO2-bgc_rsut
# NorESM1-ME_1pctCO2-bgc_rldscs
# NorESM1-ME_1pctCO2-bgc_rsdscs
# NorESM1-ME_1pctCO2-bgc_rsuscs
# NorESM1-ME_1pctCO2-bgc_rsutcs
# NorESM1-ME_1pctCO2_hfls
# NorESM1-ME_1pctCO2_hfss
# NorESM1-ME_1pctCO2_hurs
# NorESM1-ME_1pctCO2_ps
# NorESM1-ME_1pctCO2_evspsbl
# NorESM1-ME_1pctCO2_tas
# NorESM1-ME_1pctCO2_ts
# NorESM1-ME_1pctCO2_pr
# NorESM1-ME_1pctCO2_tran
# NorESM1-ME_1pctCO2_gpp
# NorESM1-ME_1pctCO2_lai
# NorESM1-ME_1pctCO2_mrro
# NorESM1-ME_1pctCO2_mrso
# NorESM1-ME_1pctCO2_rlds
# NorESM1-ME_1pctCO2_rlus
# NorESM1-ME_1pctCO2_rlut
# NorESM1-ME_1pctCO2_rsds
# NorESM1-ME_1pctCO2_rsdt
# NorESM1-ME_1pctCO2_rsus
# NorESM1-ME_1pctCO2_rsut
# NorESM1-ME_1pctCO2_rldscs
# NorESM1-ME_1pctCO2_rsdscs
# NorESM1-ME_1pctCO2_rsuscs
# NorESM1-ME_1pctCO2_rlutcs
# NorESM1-ME_1pctCO2_clt
# NorESM1-ME_1pctCO2-rad_hfls
# NorESM1-ME_1pctCO2-rad_hfss
# NorESM1-ME_1pctCO2-rad_hurs
# NorESM1-ME_1pctCO2-rad_ps
# NorESM1-ME_1pctCO2-rad_evspsbl
# NorESM1-ME_1pctCO2-rad_tas
# NorESM1-ME_1pctCO2-rad_ts
# NorESM1-ME_1pctCO2-rad_pr
# NorESM1-ME_1pctCO2-rad_tran
# NorESM1-ME_1pctCO2-rad_gpp
# NorESM1-ME_1pctCO2-rad_lai
# NorESM1-ME_1pctCO2-rad_mrro
# NorESM1-ME_1pctCO2-rad_mrso
# NorESM1-ME_1pctCO2-rad_rlds
# NorESM1-ME_1pctCO2-rad_rlus
# NorESM1-ME_1pctCO2-rad_rlut
# NorESM1-ME_1pctCO2-rad_rsds
# NorESM1-ME_1pctCO2-rad_rsdt
# NorESM1-ME_1pctCO2-rad_rsus
# NorESM1-ME_1pctCO2-rad_rsut
# NorESM1-ME_1pctCO2-rad_rldscs
# NorESM1-ME_1pctCO2-rad_rsdscs
# NorESM1-ME_1pctCO2-rad_rsuscs
# NorESM1-ME_1pctCO2-rad_rsutcs
# NorESM1-ME_1pctCO2-rad_rlutcs
# NorESM1-ME_1pctCO2-rad_clt
# NorESM1-ME_piControl_tas
# NorESM1-ME_piControl_ts
# bcc-csm1-1_areacella
# bcc-csm1-1_sftlf
# bcc-csm1-1_sftgif
# bcc-csm1-1_1pctCO2-bgc_hfls
# bcc-csm1-1_1pctCO2-bgc_hfss
# bcc-csm1-1_1pctCO2-bgc_hurs
# bcc-csm1-1_1pctCO2-bgc_huss
# bcc-csm1-1_1pctCO2-bgc_ps
# bcc-csm1-1_1pctCO2-bgc_evspsbl
# bcc-csm1-1_1pctCO2-bgc_tas
# bcc-csm1-1_1pctCO2-bgc_ts
# bcc-csm1-1_1pctCO2-bgc_pr
# bcc-csm1-1_1pctCO2-bgc_sfcWind
# bcc-csm1-1_1pctCO2-bgc_tran
# bcc-csm1-1_1pctCO2-bgc_gpp
# bcc-csm1-1_1pctCO2-bgc_lai
# bcc-csm1-1_1pctCO2-bgc_mrro
# bcc-csm1-1_1pctCO2-bgc_mrso
# bcc-csm1-1_1pctCO2-bgc_rlds
# bcc-csm1-1_1pctCO2-bgc_rlus
# bcc-csm1-1_1pctCO2-bgc_rlut
# bcc-csm1-1_1pctCO2-bgc_rsds
# bcc-csm1-1_1pctCO2-bgc_rsdt
# bcc-csm1-1_1pctCO2-bgc_rsus
# bcc-csm1-1_1pctCO2-bgc_rsut
# bcc-csm1-1_1pctCO2-bgc_rldscs
# bcc-csm1-1_1pctCO2-bgc_rsdscs
# bcc-csm1-1_1pctCO2-bgc_rsuscs
# bcc-csm1-1_1pctCO2-bgc_rsutcs
# bcc-csm1-1_1pctCO2-bgc_rlutcs
# bcc-csm1-1_1pctCO2_hfls
# bcc-csm1-1_1pctCO2_hfss
# bcc-csm1-1_1pctCO2_hurs
# bcc-csm1-1_1pctCO2_huss
# bcc-csm1-1_1pctCO2_ps
# bcc-csm1-1_1pctCO2_evspsbl
# bcc-csm1-1_1pctCO2_tas
# bcc-csm1-1_1pctCO2_ts
# bcc-csm1-1_1pctCO2_pr
# bcc-csm1-1_1pctCO2_sfcWind
# bcc-csm1-1_1pctCO2_tran
# bcc-csm1-1_1pctCO2_gpp
# bcc-csm1-1_1pctCO2_lai
# bcc-csm1-1_1pctCO2_mrro
# bcc-csm1-1_1pctCO2_mrso
# bcc-csm1-1_1pctCO2_rlds
# bcc-csm1-1_1pctCO2_rlus
# bcc-csm1-1_1pctCO2_rlut
# bcc-csm1-1_1pctCO2_rsds
# bcc-csm1-1_1pctCO2_rsdt
# bcc-csm1-1_1pctCO2_rsus
# bcc-csm1-1_1pctCO2_rsut
# bcc-csm1-1_1pctCO2_rldscs
# bcc-csm1-1_1pctCO2_rsdscs
# bcc-csm1-1_1pctCO2_rsuscs
# bcc-csm1-1_1pctCO2_rsutcs
# bcc-csm1-1_1pctCO2_rlutcs
# bcc-csm1-1_1pctCO2-rad_hfls
# bcc-csm1-1_1pctCO2-rad_hfss
# bcc-csm1-1_1pctCO2-rad_hurs
# bcc-csm1-1_1pctCO2-rad_huss
# bcc-csm1-1_1pctCO2-rad_ps
# bcc-csm1-1_1pctCO2-rad_evspsbl
# bcc-csm1-1_1pctCO2-rad_tas
# bcc-csm1-1_1pctCO2-rad_ts
# bcc-csm1-1_1pctCO2-rad_pr
# bcc-csm1-1_1pctCO2-rad_sfcWind
# bcc-csm1-1_1pctCO2-rad_tran
# bcc-csm1-1_1pctCO2-rad_gpp
# bcc-csm1-1_1pctCO2-rad_lai
# bcc-csm1-1_1pctCO2-rad_mrro
# bcc-csm1-1_1pctCO2-rad_mrso
# bcc-csm1-1_1pctCO2-rad_rlds
# bcc-csm1-1_1pctCO2-rad_rlus
# bcc-csm1-1_1pctCO2-rad_rlut
# bcc-csm1-1_1pctCO2-rad_rsds
# bcc-csm1-1_1pctCO2-rad_rsdt
# bcc-csm1-1_1pctCO2-rad_rsus
# bcc-csm1-1_1pctCO2-rad_rsut
# bcc-csm1-1_1pctCO2-rad_rldscs
# bcc-csm1-1_1pctCO2-rad_rsdscs
# bcc-csm1-1_1pctCO2-rad_rsuscs
# bcc-csm1-1_1pctCO2-rad_rsutcs
# bcc-csm1-1_1pctCO2-rad_rlutcs
# bcc-csm1-1_piControl_huss
# bcc-csm1-1_piControl_tas
# bcc-csm1-1_piControl_ts
# bcc-csm1-1_piControl_lai
# bcc-csm1-1_piControl_rldscs
# bcc-csm1-1_piControl_rsdscs
# bcc-csm1-1_piControl_rsuscs
# bcc-csm1-1_piControl_rsutcs
# bcc-csm1-1_piControl_rlutcs
# CanESM2_areacella
# CanESM2_sftlf
# CanESM2_sftgif
# CanESM2_1pctCO2-bgc_hfls
# CanESM2_1pctCO2-bgc_hfss
# CanESM2_1pctCO2-bgc_hurs
# CanESM2_1pctCO2-bgc_huss
# CanESM2_1pctCO2-bgc_ps
# CanESM2_1pctCO2-bgc_evspsbl
# CanESM2_1pctCO2-bgc_tas
# CanESM2_1pctCO2-bgc_ts
# CanESM2_1pctCO2-bgc_pr
# CanESM2_1pctCO2-bgc_sfcWind
# CanESM2_1pctCO2-bgc_tran
# CanESM2_1pctCO2-bgc_gpp
# CanESM2_1pctCO2-bgc_lai
# CanESM2_1pctCO2-bgc_mrro
# CanESM2_1pctCO2-bgc_mrso
# CanESM2_1pctCO2-bgc_rlds
# CanESM2_1pctCO2-bgc_rlus
# CanESM2_1pctCO2-bgc_rlut
# CanESM2_1pctCO2-bgc_rsds
# CanESM2_1pctCO2-bgc_rsdt
# CanESM2_1pctCO2-bgc_rsus
# CanESM2_1pctCO2-bgc_rsut
# CanESM2_1pctCO2-bgc_rldscs
# CanESM2_1pctCO2-bgc_rsdscs
# CanESM2_1pctCO2-bgc_rsuscs
# CanESM2_1pctCO2-bgc_rsutcs
# CanESM2_1pctCO2-bgc_rlutcs
# CanESM2_1pctCO2_hfls
# CanESM2_1pctCO2_hfss
# CanESM2_1pctCO2_hurs
# CanESM2_1pctCO2_huss
# CanESM2_1pctCO2_ps
# CanESM2_1pctCO2_evspsbl
# CanESM2_1pctCO2_tas
# CanESM2_1pctCO2_ts
# CanESM2_1pctCO2_pr
# CanESM2_1pctCO2_sfcWind
# CanESM2_1pctCO2_tran
# CanESM2_1pctCO2_gpp
# CanESM2_1pctCO2_lai
# CanESM2_1pctCO2_mrro
# CanESM2_1pctCO2_mrso
# CanESM2_1pctCO2_rlds
# CanESM2_1pctCO2_rlus
# CanESM2_1pctCO2_rlut
# CanESM2_1pctCO2_rsds
# CanESM2_1pctCO2_rsdt
# CanESM2_1pctCO2_rsus
# CanESM2_1pctCO2_rsut
# CanESM2_1pctCO2_rldscs
# CanESM2_1pctCO2_rsdscs
# CanESM2_1pctCO2_rsuscs
# CanESM2_1pctCO2_rsutcs
# CanESM2_1pctCO2_rlutcs
# CanESM2_1pctCO2_clt
# CanESM2_1pctCO2-rad_hfls
# CanESM2_1pctCO2-rad_hfss
# CanESM2_1pctCO2-rad_hurs
# CanESM2_1pctCO2-rad_huss
# CanESM2_1pctCO2-rad_ps
# CanESM2_1pctCO2-rad_evspsbl
# CanESM2_1pctCO2-rad_tas
# CanESM2_1pctCO2-rad_ts
# CanESM2_1pctCO2-rad_pr
# CanESM2_1pctCO2-rad_sfcWind
# CanESM2_1pctCO2-rad_tran
# CanESM2_1pctCO2-rad_gpp
# CanESM2_1pctCO2-rad_lai
# CanESM2_1pctCO2-rad_mrro
# CanESM2_1pctCO2-rad_mrso
# CanESM2_1pctCO2-rad_rlds
# CanESM2_1pctCO2-rad_rlus
# CanESM2_1pctCO2-rad_rlut
# CanESM2_1pctCO2-rad_rsds
# CanESM2_1pctCO2-rad_rsdt
# CanESM2_1pctCO2-rad_rsus
# CanESM2_1pctCO2-rad_rsut
# CanESM2_1pctCO2-rad_rldscs
# CanESM2_1pctCO2-rad_rsdscs
# CanESM2_1pctCO2-rad_rsuscs
# CanESM2_1pctCO2-rad_rsutcs
# CanESM2_1pctCO2-rad_rlutcs
# CanESM2_1pctCO2-rad_clt
# CanESM2_piControl_tas
# CanESM2_piControl_ts
# CanESM2_piControl_rldscs
# CanESM2_piControl_rsdscs
# CESM1-BGC_areacella
# CESM1-BGC_sftlf
# CESM1-BGC_sftgif
# CESM1-BGC_1pctCO2-bgc_hfls
# CESM1-BGC_1pctCO2-bgc_hfss
# CESM1-BGC_1pctCO2-bgc_hurs
# CESM1-BGC_1pctCO2-bgc_ps
# CESM1-BGC_1pctCO2-bgc_evspsbl
# CESM1-BGC_1pctCO2-bgc_tas
# CESM1-BGC_1pctCO2-bgc_ts
# CESM1-BGC_1pctCO2-bgc_pr
# CESM1-BGC_1pctCO2-bgc_sfcWind
# CESM1-BGC_1pctCO2-bgc_tran
# CESM1-BGC_1pctCO2-bgc_gpp
# CESM1-BGC_1pctCO2-bgc_lai
# CESM1-BGC_1pctCO2-bgc_mrro
# CESM1-BGC_1pctCO2-bgc_mrso
# CESM1-BGC_1pctCO2-bgc_rlds
# CESM1-BGC_1pctCO2-bgc_rlus
# CESM1-BGC_1pctCO2-bgc_rlut
# CESM1-BGC_1pctCO2-bgc_rsds
# CESM1-BGC_1pctCO2-bgc_rsdt
# CESM1-BGC_1pctCO2-bgc_rsus
# CESM1-BGC_1pctCO2-bgc_rsut
# CESM1-BGC_1pctCO2-bgc_rldscs
# CESM1-BGC_1pctCO2-bgc_rsdscs
# CESM1-BGC_1pctCO2-bgc_rsuscs
# CESM1-BGC_1pctCO2-bgc_rsutcs
# CESM1-BGC_1pctCO2-bgc_rlutcs
# CESM1-BGC_1pctCO2_hfls
# CESM1-BGC_1pctCO2_hfss
# CESM1-BGC_1pctCO2_hurs
# CESM1-BGC_1pctCO2_huss
# CESM1-BGC_1pctCO2_ps
# CESM1-BGC_1pctCO2_evspsbl
# CESM1-BGC_1pctCO2_tas
# CESM1-BGC_1pctCO2_ts
# CESM1-BGC_1pctCO2_pr
# CESM1-BGC_1pctCO2_sfcWind
# CESM1-BGC_1pctCO2_tran
# CESM1-BGC_1pctCO2_gpp
# CESM1-BGC_1pctCO2_lai
# CESM1-BGC_1pctCO2_mrro
# CESM1-BGC_1pctCO2_mrso
# CESM1-BGC_1pctCO2_rlds
# CESM1-BGC_1pctCO2_rlus
# CESM1-BGC_1pctCO2_rlut
# CESM1-BGC_1pctCO2_rsds
# CESM1-BGC_1pctCO2_rsdt
# CESM1-BGC_1pctCO2_rsus
# CESM1-BGC_1pctCO2_rsut
# CESM1-BGC_1pctCO2_rldscs
# CESM1-BGC_1pctCO2_rsdscs
# CESM1-BGC_1pctCO2_rsuscs
# CESM1-BGC_1pctCO2_rsutcs
# CESM1-BGC_1pctCO2_rlutcs
# CESM1-BGC_1pctCO2-rad_hfls
# CESM1-BGC_1pctCO2-rad_hfss
# CESM1-BGC_1pctCO2-rad_hurs
# CESM1-BGC_1pctCO2-rad_huss
# CESM1-BGC_1pctCO2-rad_ps
# CESM1-BGC_1pctCO2-rad_evspsbl
# CESM1-BGC_1pctCO2-rad_tas
# CESM1-BGC_1pctCO2-rad_ts
# CESM1-BGC_1pctCO2-rad_pr
# CESM1-BGC_1pctCO2-rad_sfcWind
# CESM1-BGC_1pctCO2-rad_tran
# CESM1-BGC_1pctCO2-rad_gpp
# CESM1-BGC_1pctCO2-rad_lai
# CESM1-BGC_1pctCO2-rad_mrro
# CESM1-BGC_1pctCO2-rad_mrso
# CESM1-BGC_1pctCO2-rad_rlds
# CESM1-BGC_1pctCO2-rad_rlus
# CESM1-BGC_1pctCO2-rad_rlut
# CESM1-BGC_1pctCO2-rad_rsds
# CESM1-BGC_1pctCO2-rad_rsdt
# CESM1-BGC_1pctCO2-rad_rsus
# CESM1-BGC_1pctCO2-rad_rsut
# CESM1-BGC_1pctCO2-rad_rldscs
# CESM1-BGC_1pctCO2-rad_rsdscs
# CESM1-BGC_1pctCO2-rad_rsuscs
# CESM1-BGC_1pctCO2-rad_rsutcs
# CESM1-BGC_1pctCO2-rad_rlutcs
# CESM1-BGC_piControl_tas
# CESM1-BGC_piControl_rldscs
# CESM1-BGC_piControl_rsdscs
# CESM1-BGC_piControl_rsuscs
# CESM1-BGC_piControl_rsutcs
# CESM1-BGC_piControl_rlutcs
# GFDL-ESM2M_areacella
# GFDL-ESM2M_sftlf
# GFDL-ESM2M_sftgif
# GFDL-ESM2M_1pctCO2-bgc_hfls
# GFDL-ESM2M_1pctCO2-bgc_hfss
# GFDL-ESM2M_1pctCO2-bgc_hurs
# GFDL-ESM2M_1pctCO2-bgc_ps
# GFDL-ESM2M_1pctCO2-bgc_evspsbl
# GFDL-ESM2M_1pctCO2-bgc_tas
# GFDL-ESM2M_1pctCO2-bgc_ts
# GFDL-ESM2M_1pctCO2-bgc_pr
# GFDL-ESM2M_1pctCO2-bgc_sfcWind
# GFDL-ESM2M_1pctCO2-bgc_tran
# GFDL-ESM2M_1pctCO2-bgc_gpp
# GFDL-ESM2M_1pctCO2-bgc_lai
# GFDL-ESM2M_1pctCO2-bgc_mrro
# GFDL-ESM2M_1pctCO2-bgc_mrso
# GFDL-ESM2M_1pctCO2-bgc_rlds
# GFDL-ESM2M_1pctCO2-bgc_rlus
# GFDL-ESM2M_1pctCO2-bgc_rlut
# GFDL-ESM2M_1pctCO2-bgc_rsds
# GFDL-ESM2M_1pctCO2-bgc_rsdt
# GFDL-ESM2M_1pctCO2-bgc_rsus
# GFDL-ESM2M_1pctCO2-bgc_rsut
# GFDL-ESM2M_1pctCO2-bgc_rldscs
# GFDL-ESM2M_1pctCO2-bgc_rsdscs
# GFDL-ESM2M_1pctCO2-bgc_rsuscs
# GFDL-ESM2M_1pctCO2-bgc_rsutcs
# GFDL-ESM2M_1pctCO2-bgc_rlutcs
# GFDL-ESM2M_1pctCO2_hfls
# GFDL-ESM2M_1pctCO2_hfss
# GFDL-ESM2M_1pctCO2_hurs
# GFDL-ESM2M_1pctCO2_ps
# GFDL-ESM2M_1pctCO2_evspsbl
# GFDL-ESM2M_1pctCO2_tas
# GFDL-ESM2M_1pctCO2_ts
# GFDL-ESM2M_1pctCO2_pr
# GFDL-ESM2M_1pctCO2_sfcWind
# GFDL-ESM2M_1pctCO2_tran
# GFDL-ESM2M_1pctCO2_gpp
# GFDL-ESM2M_1pctCO2_lai
# GFDL-ESM2M_1pctCO2_mrro
# GFDL-ESM2M_1pctCO2_mrso
# GFDL-ESM2M_1pctCO2_rlds
# GFDL-ESM2M_1pctCO2_rlus
# GFDL-ESM2M_1pctCO2_rlut
# GFDL-ESM2M_1pctCO2_rsds
# GFDL-ESM2M_1pctCO2_rsdt
# GFDL-ESM2M_1pctCO2_rsus
# GFDL-ESM2M_1pctCO2_rsut
# GFDL-ESM2M_1pctCO2_rsdscs
# GFDL-ESM2M_1pctCO2-rad_hfls
# GFDL-ESM2M_1pctCO2-rad_hfss
# GFDL-ESM2M_1pctCO2-rad_hurs
# GFDL-ESM2M_1pctCO2-rad_ps
# GFDL-ESM2M_1pctCO2-rad_evspsbl
# GFDL-ESM2M_1pctCO2-rad_tas
# GFDL-ESM2M_1pctCO2-rad_ts
# GFDL-ESM2M_1pctCO2-rad_pr
# GFDL-ESM2M_1pctCO2-rad_sfcWind
# GFDL-ESM2M_1pctCO2-rad_tran
# GFDL-ESM2M_1pctCO2-rad_gpp
# GFDL-ESM2M_1pctCO2-rad_lai
# GFDL-ESM2M_1pctCO2-rad_mrro
# GFDL-ESM2M_1pctCO2-rad_mrso
# GFDL-ESM2M_1pctCO2-rad_rlds
# GFDL-ESM2M_1pctCO2-rad_rlus
# GFDL-ESM2M_1pctCO2-rad_rlut
# GFDL-ESM2M_1pctCO2-rad_rsds
# GFDL-ESM2M_1pctCO2-rad_rsdt
# GFDL-ESM2M_1pctCO2-rad_rsus
# GFDL-ESM2M_1pctCO2-rad_rsut
# GFDL-ESM2M_1pctCO2-rad_rldscs
# GFDL-ESM2M_1pctCO2-rad_rsdscs
# GFDL-ESM2M_1pctCO2-rad_rlutcs
# GFDL-ESM2M_1pctCO2-rad_clt
# GFDL-ESM2M_piControl_tas
# GFDL-ESM2M_piControl_ts
# IPSL-CM5A-LR_areacella
# IPSL-CM5A-LR_sftlf
# IPSL-CM5A-LR_sftgif
# IPSL-CM5A-LR_1pctCO2-bgc_hfls
# IPSL-CM5A-LR_1pctCO2-bgc_hfss
# IPSL-CM5A-LR_1pctCO2-bgc_hurs
# IPSL-CM5A-LR_1pctCO2-bgc_ps
# IPSL-CM5A-LR_1pctCO2-bgc_evspsbl
# IPSL-CM5A-LR_1pctCO2-bgc_tas
# IPSL-CM5A-LR_1pctCO2-bgc_ts
# IPSL-CM5A-LR_1pctCO2-bgc_pr
# IPSL-CM5A-LR_1pctCO2-bgc_sfcWind
# IPSL-CM5A-LR_1pctCO2-bgc_tran
# IPSL-CM5A-LR_1pctCO2-bgc_gpp
# IPSL-CM5A-LR_1pctCO2-bgc_lai
# IPSL-CM5A-LR_1pctCO2-bgc_mrro
# IPSL-CM5A-LR_1pctCO2-bgc_mrso
# IPSL-CM5A-LR_1pctCO2-bgc_rlds
# IPSL-CM5A-LR_1pctCO2-bgc_rlus
# IPSL-CM5A-LR_1pctCO2-bgc_rlut
# IPSL-CM5A-LR_1pctCO2-bgc_rsds
# IPSL-CM5A-LR_1pctCO2-bgc_rsdt
# IPSL-CM5A-LR_1pctCO2-bgc_rsus
# IPSL-CM5A-LR_1pctCO2-bgc_rsut
# IPSL-CM5A-LR_1pctCO2-bgc_rsdscs
# IPSL-CM5A-LR_1pctCO2-bgc_rsuscs
# IPSL-CM5A-LR_1pctCO2-bgc_rsutcs
# IPSL-CM5A-LR_1pctCO2-bgc_rlutcs
# IPSL-CM5A-LR_1pctCO2_hfls
# IPSL-CM5A-LR_1pctCO2_hfss
# IPSL-CM5A-LR_1pctCO2_hurs
# IPSL-CM5A-LR_1pctCO2_ps
# IPSL-CM5A-LR_1pctCO2_evspsbl
# IPSL-CM5A-LR_1pctCO2_tas
# IPSL-CM5A-LR_1pctCO2_ts
# IPSL-CM5A-LR_1pctCO2_pr
# IPSL-CM5A-LR_1pctCO2_sfcWind
# IPSL-CM5A-LR_1pctCO2_tran
# IPSL-CM5A-LR_1pctCO2_gpp
# IPSL-CM5A-LR_1pctCO2_lai
# IPSL-CM5A-LR_1pctCO2_mrro
# IPSL-CM5A-LR_1pctCO2_mrso
# IPSL-CM5A-LR_1pctCO2_rlds
# IPSL-CM5A-LR_1pctCO2_rlus
# IPSL-CM5A-LR_1pctCO2_rlut
# IPSL-CM5A-LR_1pctCO2_rsds
# IPSL-CM5A-LR_1pctCO2_rsdt
# IPSL-CM5A-LR_1pctCO2_rsus
# IPSL-CM5A-LR_1pctCO2_rsut
# IPSL-CM5A-LR_1pctCO2_rldscs
# IPSL-CM5A-LR_1pctCO2_rsdscs
# IPSL-CM5A-LR_1pctCO2_rsuscs
# IPSL-CM5A-LR_1pctCO2_rsutcs
# IPSL-CM5A-LR_1pctCO2_rlutcs
# IPSL-CM5A-LR_1pctCO2_clt
# IPSL-CM5A-LR_1pctCO2-rad_hfls
# IPSL-CM5A-LR_1pctCO2-rad_hfss
# IPSL-CM5A-LR_1pctCO2-rad_hurs
# IPSL-CM5A-LR_1pctCO2-rad_ps
# IPSL-CM5A-LR_1pctCO2-rad_evspsbl
# IPSL-CM5A-LR_1pctCO2-rad_tas
# IPSL-CM5A-LR_1pctCO2-rad_ts
# IPSL-CM5A-LR_1pctCO2-rad_pr
# IPSL-CM5A-LR_1pctCO2-rad_sfcWind
# IPSL-CM5A-LR_1pctCO2-rad_tran
# IPSL-CM5A-LR_1pctCO2-rad_gpp
# IPSL-CM5A-LR_1pctCO2-rad_lai
# IPSL-CM5A-LR_1pctCO2-rad_mrro
# IPSL-CM5A-LR_1pctCO2-rad_mrso
# IPSL-CM5A-LR_1pctCO2-rad_rlds
# IPSL-CM5A-LR_1pctCO2-rad_rlus
# IPSL-CM5A-LR_1pctCO2-rad_rlut
# IPSL-CM5A-LR_1pctCO2-rad_rsds
# IPSL-CM5A-LR_1pctCO2-rad_rsdt
# IPSL-CM5A-LR_1pctCO2-rad_rsus
# IPSL-CM5A-LR_1pctCO2-rad_rsut
# IPSL-CM5A-LR_1pctCO2-rad_rsdscs
# IPSL-CM5A-LR_1pctCO2-rad_rsuscs
# IPSL-CM5A-LR_1pctCO2-rad_rsutcs
# IPSL-CM5A-LR_1pctCO2-rad_rlutcs
# IPSL-CM5A-LR_1pctCO2-rad_clt
# IPSL-CM5A-LR_piControl_tas
# IPSL-CM5A-LR_piControl_ts
# MIROC-ESM_areacella
# MIROC-ESM_sftlf
# MIROC-ESM_sftgif
# MIROC-ESM_1pctCO2_hfls
# MIROC-ESM_1pctCO2_hfss
# MIROC-ESM_1pctCO2_hurs
# MIROC-ESM_1pctCO2_ps
# MIROC-ESM_1pctCO2_evspsbl
# MIROC-ESM_1pctCO2_tas
# MIROC-ESM_1pctCO2_pr
# MIROC-ESM_1pctCO2_sfcWind
# MIROC-ESM_1pctCO2_tran
# MIROC-ESM_1pctCO2_gpp
# MIROC-ESM_1pctCO2_lai
# MIROC-ESM_1pctCO2_mrro
# MIROC-ESM_1pctCO2_mrso
# MRI-ESM1_areacella
# MRI-ESM1_sftlf
# MRI-ESM1_1pctCO2-bgc_hfls
# MRI-ESM1_1pctCO2-bgc_hfss
# MRI-ESM1_1pctCO2-bgc_hurs
# MRI-ESM1_1pctCO2-bgc_huss
# MRI-ESM1_1pctCO2-bgc_ps
# MRI-ESM1_1pctCO2-bgc_evspsbl
# MRI-ESM1_1pctCO2-bgc_tas
# MRI-ESM1_1pctCO2-bgc_pr
# MRI-ESM1_1pctCO2-bgc_sfcWind
# MRI-ESM1_1pctCO2-bgc_tran
# MRI-ESM1_1pctCO2-bgc_gpp
# MRI-ESM1_1pctCO2-bgc_lai
# MRI-ESM1_1pctCO2-bgc_mrro
# MRI-ESM1_1pctCO2-bgc_mrso
# MRI-ESM1_1pctCO2-bgc_rldscs
# MRI-ESM1_1pctCO2-bgc_rsdscs
# MRI-ESM1_1pctCO2-bgc_rsuscs
# MRI-ESM1_1pctCO2-bgc_rsutcs
# MRI-ESM1_1pctCO2-bgc_rlutcs
# BNU-ESM_areacella
# BNU-ESM_sftlf
# BNU-ESM_1pctCO2_hfls
# BNU-ESM_1pctCO2_hfss
# BNU-ESM_1pctCO2_hurs
# BNU-ESM_1pctCO2_ps
# BNU-ESM_1pctCO2_evspsbl
# BNU-ESM_1pctCO2_tas
# BNU-ESM_1pctCO2_pr
# BNU-ESM_1pctCO2_sfcWind
# BNU-ESM_1pctCO2_tran
# BNU-ESM_1pctCO2_gpp
# BNU-ESM_1pctCO2_lai
# BNU-ESM_1pctCO2_mrro
# BNU-ESM_1pctCO2_mrso
