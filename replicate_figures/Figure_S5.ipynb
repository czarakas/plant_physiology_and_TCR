# %% [markdown]
# # Set up workspace

# %%
import sys
sys.path.append('../')

# %%
# %matplotlib inline
import pickle
import sys
import numpy as np
import matplotlib.pyplot as plt

# %%
from plants_and_TCR.analysis_parameters import directory_information
from plants_and_TCR.analyze_data import grab_cmip_dataset
from plants_and_TCR.analysis_parameters import get_CMIP_info
from plants_and_TCR.generate_figures import quick_map
from plants_and_TCR.generate_figures import plot_allmaps_run

# %%
DIR_FIGURES = directory_information.DIR_OUTPUT_FIGURES
DIR_DICTS = directory_information.DIR_DATA_DICTIONARIES
cmip_dict = pickle.load(open(DIR_DICTS+'cmip_dict.pickle',"rb"))

# %% [markdown]
# # Maps for All Models

# %%
VARNAME='tas'
END_YR=70

# %%
import importlib
importlib.reload(plot_allmaps_run)
# Out:
# <module 'plants_and_TCR.generate_figures.plot_allmaps_run' from '../plants_and_TCR/generate_figures/plot_allmaps_run.py'>

# %%
#Runname order: ['1pctCO2-rad','1pctCO2-bgc','1pctCO2','piControl']
[fig,
 mapdata_all,
 latdata_all,
 londata_all] = plot_allmaps_run.plot_allmaps_run(runname_inds=[1,3],#[2,0],
                                                  varname=VARNAME,
                                                  end_yr=END_YR,
                                                  clim=[-1.6,1.7],
                                                  unitname=None,
                                                  contours=True,
                                                  color_interval=0.2,
                                                  cmap=plt.cm.bwr,#plt.cm.bwr,
                                                  filename= DIR_FIGURES+'Maps_Tas_'+str(END_YR)+'yr',
                                                  mask_type=None,
                                                  show_fig = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/core/dataarray.py in _getitem_coord(self, key)
#     615         try:
# --> 616             var = self._coords[key]
#     617         except KeyError:
#
# KeyError: 'time.year'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-b22aef617555> in <module>
#      13                                                   filename= DIR_FIGURES+'Maps_Tas_'+str(END_YR)+'yr',
#      14                                                   mask_type=None,
# ---> 15                                                   show_fig = True)
#
# /eos9/czarakas/Code/plants_and_TCR/plants_and_TCR/generate_figures/plot_allmaps_run.py in plot_allmaps_run(runname_inds, varname, end_yr, clim, cmap, contours, color_interval, extend_choice, unitname, filename, mask_type, show_fig)
#      59
#      60             if ((ds2 is not None) and (ds1 is not None)): #
# ---> 61                 vals2 = ds2[varname].groupby('time.year').mean(dim='time')
#      62                 vals1 = ds1[varname].groupby('time.year').mean(dim='time')
#      63                 if runname1 == 'piControl':
#
# ~/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/core/common.py in groupby(self, group, squeeze, restore_coord_dims)
#     662         """
#     663         return self._groupby_cls(
# --> 664             self, group, squeeze=squeeze, restore_coord_dims=restore_coord_dims
#     665         )
#     666
#
# ~/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/core/groupby.py in __init__(self, obj, group, squeeze, grouper, bins, restore_coord_dims, cut_kwargs)
#     311                     "name of an xarray variable or dimension"
#     312                 )
# --> 313             group = obj[group]
#     314             if len(group) == 0:
#     315                 raise ValueError(f"{group.name} must not be empty")
#
# ~/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/core/dataarray.py in __getitem__(self, key)
#     625     def __getitem__(self, key: Any) -> "DataArray":
#     626         if isinstance(key, str):
# --> 627             return self._getitem_coord(key)
#     628         else:
#     629             # xarray-style array indexing
#
# ~/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/core/dataarray.py in _getitem_coord(self, key)
#     618             dim_sizes = dict(zip(self.dims, self.shape))
#     619             _, key, var = _get_virtual_variable(
# --> 620                 self._coords, key, self._level_coords, dim_sizes
#     621             )
#     622
#
# ~/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/xarray/core/dataset.py in _get_virtual_variable(variables, key, level_vars, dim_sizes)
#     173             data = getattr(ref_var.dt, var_name).data
#     174         else:
# --> 175             data = getattr(ref_var, var_name).data
#     176         virtual_var = Variable(ref_var.dims, data)
#     177
#
# AttributeError: 'IndexVariable' object has no attribute 'year'
