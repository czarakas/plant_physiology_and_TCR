# %% [markdown]
# ##### ----------------------Notes---------------------
# * This code uses regridded datafiles.
#
# ##### ------------------------------------------------

# %% [markdown]
# ### Set up workspace

# %%
import sys
sys.path.append('../')

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import numpy as np

from plants_and_TCR.analysis_parameters import get_CMIP_info
from plants_and_TCR.analysis_parameters import directory_information
from plants_and_TCR.generate_figures import quick_map
from plants_and_TCR.process_data import regrid_and_process_datafiles
from plants_and_TCR.process_data import make_processed_data_dict
from plants_and_TCR.analyze_data import ET_stats
from plants_and_TCR.analyze_data import multi_model_stats as mms

PATH_REGRIDDED_DATA = directory_information.DIR_PROCESSED_DATA
rc('font',**{'family':'sans-serif','sans-serif':['Arial']})

# %% [markdown]
# ### Regrid Data (only do this once)

# %%
regrid_and_process_datafiles.process_data(varname='albedo')

regrid_and_process_datafiles.process_data(varname='ET')
# Out:
# albedo_1pctCO2-rad_CMIP5_bcc-csm1-1
# Overwrite existing file: bilinear_64x128_192x288_peri.nc
#  You can set reuse_weights=True to save computing time.
# using dimensions ('lat', 'lon') from data variable albedo as the horizontal dimensions for this dataset.
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*args2)
# albedo_1pctCO2-bgc_CMIP5_bcc-csm1-1
# Overwrite existing file: bilinear_64x128_192x288_peri.nc
#  You can set reuse_weights=True to save computing time.
# using dimensions ('lat', 'lon') from data variable albedo as the horizontal dimensions for this dataset.
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_v3/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*args2)
# albedo_1pctCO2_CMIP5_bcc-csm1-1
# Overwrite existing file: bilinear_64x128_192x288_peri.nc
# ...

# %% [markdown]
# ### Make data dictionaries of processed files for data variable

# %%
print('------------------------ALBEDO-----------------------------')
PROC_DATA_DICT_ALBEDO = make_processed_data_dict.create_variable_dictionary(runnames=['1pctCO2', '1pctCO2-rad'],
                                                                            varname='albedo',
                                                                            cdict_names=['CMIP5','CMIP6'],
                                                                            input_path=PATH_REGRIDDED_DATA)
print('-------------------------ET-----------------------------')
PROC_DATA_DICT_ET = make_processed_data_dict.create_variable_dictionary(runnames=['1pctCO2', '1pctCO2-rad'],
                                                                        varname='ET',
                                                                        cdict_names=['CMIP5','CMIP6'],
                                                                        input_path=PATH_REGRIDDED_DATA)
# Out:
# ------------------------ALBEDO-----------------------------
# -------------------------ET-----------------------------

# %% [markdown]
# ### Calculate changes in variables

# %%
CMIP_NAMES=['CMIP5','CMIP6']
END_YR=70

# %%
all_models_ALBEDO_delta = ET_stats.get_mm_mean(proc_data_dict=PROC_DATA_DICT_ALBEDO,
                                               varname='albedo',
                                               end_yr=END_YR,
                                               runname_inds=[2,0],
                                               cmip_names=CMIP_NAMES,
                                               delta_or_baseline='Delta')

all_models_ET_delta = ET_stats.get_mm_mean(proc_data_dict=PROC_DATA_DICT_ET,
                                           varname='ET',
                                           end_yr=END_YR,
                                           runname_inds=[2,0],
                                           cmip_names=CMIP_NAMES,
                                           delta_or_baseline='Delta')

# %% [markdown]
# ### Make Multimodel Mean Zonal Mean

# %%
ds_list = [all_models_ET_delta, all_models_ALBEDO_delta]
varname_list = ['ET','albedo']
varname_long_list = ['Evapotranspiration','Albedo']
cmip6_start_ind=8;
cmip6_end_ind=20;
unit_list = ['(mm/day)','']
xlims = [-60,90]
lwidth = 6
FONTSIZE = 60
land_frac_cutoff = 0.8


output_path=directory_information.DIR_OUTPUT_FIGURES
filename='ET_Albedo_ZonalMean_year'+str(END_YR)
colors=get_CMIP_info.get_colors('CMIP5and6')[cmip6_start_ind:cmip6_end_ind]

# %%
def format_subplot(term,color=None,legend_on=True):
    plt.plot(xlims,[0,0],'-k')
    land_frac = (ds['da_land']/100)*(1-(ds['da_glac']/100))
    for i in range(0,len(term['modelname'].values)):
        mapdata_mmean=term.isel(modelname=[i]).mean(dim=['modelname'])
        mapdata_mmean=mapdata_mmean*land_frac
        mapdata_mmean=mapdata_mmean.where(land_frac>land_frac_cutoff)
        lats = mapdata_mmean['lat']
        if color==None:
            plt.plot(lats,mapdata_mmean.mean(dim='lon'),linestyle='-',linewidth=lwidth, label=term['modelname'][i].values)
        elif len(color)==1:
            plt.plot(lats,mapdata_mmean.mean(dim='lon'),color=color,linestyle='-',linewidth=lwidth, label=term['modelname'][i].values)
        else:
            plt.plot(lats,mapdata_mmean.mean(dim='lon'),color=color[i],linestyle='-',linewidth=lwidth, label=term['modelname'][i].values)
    plt.xlim(xlims)
    ax.yaxis.grid()
    if legend_on:
        plt.legend(fontsize=FONTSIZE*0.7,ncol=3)
        plt.rcParams['legend.loc'] = 'lower left'

# %%
fig, ax = plt.subplots(figsize=(30,18*2))
for i in range(0,len(ds_list)):
    ds = ds_list[i]
    varname = varname_list[i]
    varname_long = varname_long_list[i]
    units = unit_list[i]
    ax = plt.subplot(2, 1, i+1)
    
    term = ds[varname].isel(modelname=range(cmip6_start_ind, cmip6_end_ind)).mean(dim=['time'])
    lats = term['lat']
    land_frac = (ds['da_land']/100)*(1-(ds['da_glac']/100))
    
    #mapdata_mmean = term.mean(dim=['lon','modelname'])
    
    
    # calculate and filter multi-model mean
    mapdata_mmean=term.mean(dim=['modelname'])
    mapdata_mmean=mapdata_mmean.where(abs(mapdata_mmean)<10)*land_frac
    mapdata_mmean=mapdata_mmean.where(land_frac>land_frac_cutoff)
    
    #plot multimodel mean
    plt.plot(lats,mapdata_mmean.mean(dim='lon'),label='Multi-Model Mean',
             linestyle='-',color='black',linewidth=lwidth*3,alpha=0.5)
    
    # plot individual models
    if i==1:
        format_subplot(term,colors,legend_on=True)
    else:
        format_subplot(term,colors,legend_on=False)

    if END_YR==70:
        plt.title('2xCO2')
    elif END_YR==130:
        plt.title('4xCO2')
    
    plt.ylabel('Change in '+varname_long+' '+units)
    
    for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
              ax.get_xticklabels() + ax.get_yticklabels()):
        item.set_fontsize(FONTSIZE)

plt.xlabel('Latitude')
fig.savefig(output_path+filename+'.png', bbox_inches='tight')
# Out:
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_bokeh/lib/python3.7/site-packages/xarray/core/nanops.py:142: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_bokeh/lib/python3.7/site-packages/xarray/core/nanops.py:142: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_bokeh/lib/python3.7/site-packages/xarray/core/nanops.py:142: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_bokeh/lib/python3.7/site-packages/xarray/core/nanops.py:142: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# /home/disk/p/czarakas/anaconda3/envs/plants_and_TCR_bokeh/lib/python3.7/site-packages/xarray/core/nanops.py:142: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# ...
